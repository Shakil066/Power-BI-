# %%
import pandas as pd

# %%
import pandas as pd

# Replace 'ISO-8859-1' with the appropriate encoding for your file if needed
df = pd.read_csv("2021_rws.csv", encoding='ISO-8859-1')

# Now you can work with the DataFrame 'df'

# %%
df.shape
# Out:
# (1512, 109)

# %%
df.columns
# Out:
# Index(['Response ID', 'What year were you born?  ', 'What is your gender?  ',
#        'How long have you been in your current job?  If you have more than one job, please answer all questions for your main job.  ',
#        'Which of the following best describes your industry?  ',
#        'Which of the following best describes your current occupation?  ',
#        'How many people are currently employed by your organisation?   ',
#        'Which of the following best describes your household?  ',
#        'Metro or Regional',
#        'Thinking about your current job, how much of your work time did you spend working remotely in the last quarter of last year?   This means October-December 2020  If you work a 5 day week, each day of remote working equals 20% of your time.  ',
#        ...
#        'How strongly do you agree or disagree with the following statements?    - Offering remote work helps me retain employees',
# ...

# %%
column_names = df.columns

# Now, you can print the column names
print(column_names)
# Out:
# Index(['Response ID', 'What year were you born?  ', 'What is your gender?  ',
#        'How long have you been in your current job?  If you have more than one job, please answer all questions for your main job.  ',
#        'Which of the following best describes your industry?  ',
#        'Which of the following best describes your current occupation?  ',
#        'How many people are currently employed by your organisation?   ',
#        'Which of the following best describes your household?  ',
#        'Metro or Regional',
#        'Thinking about your current job, how much of your work time did you spend working remotely in the last quarter of last year?   This means October-December 2020  If you work a 5 day week, each day of remote working equals 20% of your time.  ',
#        ...
#        'How strongly do you agree or disagree with the following statements?    - Offering remote work helps me retain employees',
# ...

# %%
column_names_list = column_names.tolist()

# Print all the column names
for col_name in column_names_list:
    print(col_name)
# Out:
# Response ID
# What year were you born?
# What is your gender?
# How long have you been in your current job?  If you have more than one job, please answer all questions for your main job.
# Which of the following best describes your industry?
# Which of the following best describes your current occupation?
# How many people are currently employed by your organisation?
# Which of the following best describes your household?
# Metro or Regional
# Thinking about your current job, how much of your work time did you spend working remotely in the last quarter of last year?   This means October-December 2020  If you work a 5 day week, each day of remote working equals 20% of your time.
# How much of your work time would you have preferred to work remotely during the last quarter of last year?   This means October-December 2020  If you work a 5 day week, each day of remote working equals 20% of your time.
# ...

# %%
# Define the short names as strings
short_names = [
    "Response ID",
    "Birth Year",
    "Gender",
    "Job Tenure",
    "Industry",
    "Occupation",
    "Organization Size",
    "Household Type",
    "Metro or Regional",
    "Remote Q4 2020",
    "Preferred Remote Q4 2020",
    "Remote This Year",
    "Preferred Remote This Year",
    "Post-COVID Remote",
    "Remote Policy Change",
    "Part-Remote Past 6 Months",
    "Part-Remote Frequency",
    "Part-Remote Preference",
    "Mandatory Workplace Presence",
    "Mandatory Workplace Time",
    "Remote Policy Suitability",
    "Remote Work Choice",
    "Remote Workday Choice",
    "Manager Discretion",
    "Remote Policy Satisfaction",
    "Encouragement of Remote Work",
    "Organization Readiness",
    "Common Remote Work",
    "Ease of Remote Permission",
    "Remote Collaboration",
    "Remote Promotion Concerns",
    "Remote Break Frequency",
    "Employer's Remote Impact",
    "Remote Work Support",
    "Remote Work Encouragement",
    "Remote Work Support Changes",
    "Workplace Time Allocation",
    "Workplace Preparation Time",
    "Workplace Working Time",
    "Workplace Care Responsibilities",
    "Workplace Personal Time",
    "Workplace Sleep Time",
    "Remote Prep and Commute",
    "Remote Working Time",
    "Remote Care Responsibilities",
    "Remote Personal Time",
    "Remote Sleep Time",
    "Pay Cut for Remote Option",
    "Maximum Pay Cut Accepted",
    "Remote Working Barriers (Caring)",
    "Change in Connectivity Barrier",
    "Change in Org. Software & Systems Barrier",
    "Change in Collaboration Barrier",
    "Change in Poor Management Barrier",
    "Change in IT Equipment Barrier",
    "Change in Isolation Barrier",
    "Change in Extra Costs Barrier",
    "Change in Cyber Security Barrier",
    "Change in Incompatible Tasks Barrier",
    "Change in Workspace Barrier",
    "Change in Motivation Barrier",
    "Change in Management's Attitude Barrier",
    "Change in Living Situation Barrier",
    "Change in Remote Work Skills Barrier",
    "Change in Health & Safety Barrier",
    "Colleague Remote Work Barriers (Biggest)",
    "Colleague Remote Work Barriers (Smallest)",
    "Colleague Remote Work Barriers (Biggest 2)",
    "Colleague Remote Work Barriers (Smallest 2)",
    "Colleague Remote Work Barriers (Biggest 3)",
    "Colleague Remote Work Barriers (Smallest 3)",
    "Colleague Remote Work Barriers (Biggest 4)",
    "Colleague Remote Work Barriers (Smallest 4)",
    "Colleague Remote Work Barriers (Biggest 5)",
    "Colleague Remote Work Barriers (Smallest 5)",
    "Performance of Tasks in Remote Work (Manager Communication)",
    "Performance of Tasks in Remote Work (Colleague Communication)",
    "Performance of Tasks in Remote Work (Decision Making)",
    "Performance of Tasks in Remote Work (Problem Solving)",
    "Performance of Tasks in Remote Work (Creativity & Innovation)",
    "Performance of Tasks in Remote Work (Technology Use)",
    "Performance of Tasks in Remote Work (Time Management)",
    "Performance of Tasks in Remote Work (Stress Management)",
    "Performance of Tasks in Remote Work (Networking)",
    "Performance of Tasks in Remote Work (Team Leadership)",
    "Performance of Tasks in Remote Work (Conflict Management)",
    "Performance of Tasks in Remote Work (People Management)",
    "Performance of Tasks in Remote Work (Presentation Skills)",
    "Performance of Tasks in Remote Work (Writing Skills)",
    "Performance of Tasks in Remote Work (Analysis & Reporting)",
    "Performance of Tasks in Remote Work (Project Management)",
    "Performance of Tasks in Remote Work (Financial Management)",
    "Performance of Tasks in Remote Work (Productivity & Efficiency)",
    "Performance of Tasks in Remote Work (Adaptation to Change)",
    "Performance of Tasks in Remote Work (Learning)",
    "Performance of Tasks in Remote Work (Self-Motivation)",
    "Performance of Tasks in Remote Work (Health & Safety)",
    "Performance of Tasks in Remote Work (Networking)_1",
    "Performance of Tasks in Remote Work (Stress Management)_1",
    "Biggest Personal Remote Work Barrier",
    "Economic Impact of Remote Work",
    "Societal Impact of Remote Work",
    "Environmental Impact of Remote Work",
    "Personal Wellbeing Impact of Remote Work",
    "Income/Career Impact of Remote Work",
    "Productivity Impact of Remote Work",
    "Work-Life Balance Impact of Remote Work",
    "Biggest Personal Positive Impact of Remote Work",
    "Biggest Personal Negative Impact of Remote Work"
]

# %%
a=len(short_names)

# %%
a
# Out:
# 109

# %%
df.columns = short_names

# %%
df.columns
# Out:
# Index(['Response ID', 'Birth Year', 'Gender', 'Job Tenure', 'Industry',
#        'Occupation', 'Organization Size', 'Household Type',
#        'Metro or Regional', 'Remote Q4 2020',
#        ...
#        'Biggest Personal Remote Work Barrier',
#        'Economic Impact of Remote Work', 'Societal Impact of Remote Work',
#        'Environmental Impact of Remote Work',
#        'Personal Wellbeing Impact of Remote Work',
#        'Income/Career Impact of Remote Work',
#        'Productivity Impact of Remote Work',
#        'Work-Life Balance Impact of Remote Work',
#        'Biggest Personal Positive Impact of Remote Work',
#        'Biggest Personal Negative Impact of Remote Work'],
#       dtype='object', length=109)

# %%
df.to_csv('dataset_2021.csv', index=False)

# %%
df.head()
# Out:
#    Response ID  Birth Year  Gender               Job Tenure  \
# 0            1        1976    Male        More than 5 years
# 1            2        1971    Male        More than 5 years
# 2            3        1978  Female  Between 6 and 12 months
# 3            4        1962  Female    Between 1 and 5 years
# 4            5        1974    Male        More than 5 years
#
#                             Industry  \
# 0                     Other Services
# 1                       Construction
# 2            Financial and Insurance
# 3  Health Care and Social Assistance
# 4            Financial and Insurance
#
#                                           Occupation   Organization Size  \
# 0                  Professionals - ICT Professionals       More than 200
# 1                  Professionals - ICT Professionals       More than 200
# 2  Professionals - Business, Human Resource and M...       More than 200
# 3               Professionals - Health Professionals  Between 20 and 199
# ...

# %%
(df.isnull().sum())/100
# Out:
# Response ID                                                         0.00
# Birth Year                                                          0.00
# Gender                                                              0.00
# Job Tenure                                                          0.00
# Industry                                                            0.00
# Occupation                                                          0.00
# Organization Size                                                   0.00
# Household Type                                                      0.00
# Metro or Regional                                                   0.00
# Remote Q4 2020                                                      0.00
# Preferred Remote Q4 2020                                            0.00
# Remote This Year                                                    0.00
# Preferred Remote This Year                                          0.00
# ...

# %%
pd.set_option('display.max_rows', None)

# Calculate the null values and print
null_counts = (df.isnull().sum()) / 100
print(null_counts)
# Out:
# Response ID                                                         0.00
# Birth Year                                                          0.00
# Gender                                                              0.00
# Job Tenure                                                          0.00
# Industry                                                            0.00
# Occupation                                                          0.00
# Organization Size                                                   0.00
# Household Type                                                      0.00
# Metro or Regional                                                   0.00
# Remote Q4 2020                                                      0.00
# Preferred Remote Q4 2020                                            0.00
# Remote This Year                                                    0.00
# Preferred Remote This Year                                          0.00
# ...

# %%
df.dtypes.value_counts()
# Out:
# object     96
# float64    11
# int64       2
# Name: count, dtype: int64

# %%
object_columns = df.select_dtypes(include=['object'])

# Identify numerical columns (int or float)
numerical_columns = df.select_dtypes(include=['int64', 'float64'])

# %%
for column in object_columns.columns:
    mode_value = df[column].mode().iloc[0]
    df[column].fillna(mode_value, inplace=True)

# %%
for column in numerical_columns.columns:
    median_value = df[column].median()
    df[column].fillna(median_value, inplace=True)

# %%
null_counts = (df.isnull().sum()) / 100
print(null_counts)
# Out:
# Response ID                                                        0.0
# Birth Year                                                         0.0
# Gender                                                             0.0
# Job Tenure                                                         0.0
# Industry                                                           0.0
# Occupation                                                         0.0
# Organization Size                                                  0.0
# Household Type                                                     0.0
# Metro or Regional                                                  0.0
# Remote Q4 2020                                                     0.0
# Preferred Remote Q4 2020                                           0.0
# Remote This Year                                                   0.0
# Preferred Remote This Year                                         0.0
# ...

# %%
df.to_csv('clean_2021.csv', index=False)

# %%
import pandas as pd

# %%
data=pd.read_csv("2020_rws.csv", encoding='ISO-8859-1')

# %%
data.columns
# Out:
# Index(['Response ID', 'What year were you born?', 'What is your gender?',
#        'Which of the following best describes your industry?',
#        'Which of the following best describes your industry? (Detailed)',
#        'Which of the following best describes your current occupation?',
#        'Which of the following best describes your current occupation? (Detailed)',
#        'How many people are currently employed by your organisation?',
#        'Do you manage people as part of your current occupation?',
#        'Which of the following best describes your household?',
#        'How long have you been in your current job?', 'Metro / Regional',
#        'Thinking about your current job, how much of your time did you spend remote working last year?',
#        'Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - My organisation encouraged people to work remotely',
# ...

# %%
data.shape
# Out:
# (1507, 73)

# %%
shortened_column_names = [
    'Response ID', 'Birth Year', 'Gender', 'Industry', 'Industry (Detailed)',
    'Occupation', 'Occupation (Detailed)', 'Employment Size', 'Manages People',
    'Household Description', 'Tenure in Current Job', 'Metro/Regional',
    'Time Remote Last Year', 'Org Encouraged Remote Last Year',
    'Org Prepared for Remote Last Year', 'Common for Org to Remote Last Year',
    'Easy to Get Permission to Remote Last Year', 'Collaboration When Remote Last Year',
    'Recommend Remote Last Year', 'Preferred Remote Last Year',
    'Time Remote Last 3 Months', 'Org Encouraged Remote Last 3 Months',
    'Org Prepared for Remote Last 3 Months', 'Common for Org to Remote Last 3 Months',
    'Easy to Get Permission to Remote Last 3 Months', 'Collaboration When Remote Last 3 Months',
    'Recommend Remote Last 3 Months', 'Preferred Remote Last 3 Months',
    'Preferred Remote Post-COVID', 'Employer Encourages Remote Post-COVID',
    'Employer Support for Remote Post-COVID', 'More Choice for Remote Post-COVID',
    'Productivity When Remote vs. Office', 'Commute and Prep (Office)',
    'Working Hours (Office)', 'Personal and Family Time (Office)',
    'Caring and Domestic Responsibilities (Office)', 'Commute and Prep (Remote)',
    'Working Hours (Remote)', 'Personal and Family Time (Remote)',
    'Caring and Domestic Responsibilities (Remote)', 'Most Significant Remote Barrier',
    'Least Significant Remote Barrier', 'Most Significant Remote Barrier (Cybersecurity)',
    'Least Significant Remote Barrier (Cybersecurity)', 'Most Significant Remote Barrier (Workspace)',
    'Least Significant Remote Barrier (Workspace)', 'Most Significant Remote Barrier (Living Situation)',
    'Least Significant Remote Barrier (Living Situation)', 'Most Significant Remote Barrier (IT Equipment)',
    'Least Significant Remote Barrier (IT Equipment)', 'Most Significant Remote Barrier (Collaboration)',
    'Least Significant Remote Barrier (Collaboration)', 'Most Significant Remote Barrier (Motivation)',
    'Least Significant Remote Barrier (Motivation)', 'Most Significant Remote Barrier (Software and Systems)',
    'Least Significant Remote Barrier (Software and Systems)', 'Most Significant Remote Barrier (Remote Working Skills)',
    'Least Significant Remote Barrier (Remote Working Skills)', 'Most Significant Remote Barrier (Management)',
    'Least Significant Remote Barrier (Management)', 'Best Aspect of Remote (Family Responsibilities)',
    'Worst Aspect of Remote (Family Responsibilities)', 'Best Aspect of Remote (Working Relationships)',
    'Worst Aspect of Remote (Working Relationships)', 'Best Aspect of Remote (Commute)',
    'Worst Aspect of Remote (Commute)', 'Best Aspect of Remote (Working Hours)',
    'Worst Aspect of Remote (Working Hours)', 'Best Aspect of Remote (Work-Life Balance)',
    'Worst Aspect of Remote (Work-Life Balance)', 'Best Aspect of Remote (On-the-Job Learning Opportunities)',
    'Worst Aspect of Remote (On-the-Job Learning Opportunities)'
]

# Print the list
print(shortened_column_names)
# Out:
# ['Response ID', 'Birth Year', 'Gender', 'Industry', 'Industry (Detailed)', 'Occupation', 'Occupation (Detailed)', 'Employment Size', 'Manages People', 'Household Description', 'Tenure in Current Job', 'Metro/Regional', 'Time Remote Last Year', 'Org Encouraged Remote Last Year', 'Org Prepared for Remote Last Year', 'Common for Org to Remote Last Year', 'Easy to Get Permission to Remote Last Year', 'Collaboration When Remote Last Year', 'Recommend Remote Last Year', 'Preferred Remote Last Year', 'Time Remote Last 3 Months', 'Org Encouraged Remote Last 3 Months', 'Org Prepared for Remote Last 3 Months', 'Common for Org to Remote Last 3 Months', 'Easy to Get Permission to Remote Last 3 Months', 'Collaboration When Remote Last 3 Months', 'Recommend Remote Last 3 Months', 'Preferred Remote Last 3 Months', 'Preferred Remote Post-COVID', 'Employer Encourages Remote Post-COVID', 'Employer Support for Remote Post-COVID', 'More Choice for Remote Post-COVID', 'Productivity When Remote vs. Office
# ...

# %%
len(shortened_column_names)
# Out:
# 73

# %%
data.columns=shortened_column_names

# %%
data.head()
# Out:
#    Response ID  Birth Year  Gender  \
# 0            1        1972  Female
# 1            2        1972    Male
# 2            3        1982    Male
# 3            4        1987  Female
# 4            5        1991    Male
#
#                                           Industry  \
# 0                                    Manufacturing
# 1                                  Wholesale Trade
# 2       Electricity, Gas, Water and Waste Services
# 3  Professional, Scientific and Technical Services
# 4                Transport, Postal and Warehousing
#
#                                Industry (Detailed)  \
# 0                       Food Product Manufacturing
# 1                          Other Goods Wholesaling
# 2                                       Gas Supply
# 3  Professional, Scientific and Technical Services
# 4                                  Other Transport
#
#                      Occupation  \
# 0  Clerical and administrative
# 1                      Managers
# ...

# %%
data.dtypes.value_counts()
# Out:
# object     63
# float64     8
# int64       2
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', None)
print('the percentages of null ', (data.isnull().sum()/len(data))*100)
print(data.dtypes)
# Out:
# the percentages of null  Response ID                                                    0.000000
# Birth Year                                                     0.000000
# Gender                                                         0.000000
# Industry                                                       0.000000
# Industry (Detailed)                                            0.000000
# Occupation                                                     0.000000
# Occupation (Detailed)                                          0.000000
# Employment Size                                                0.000000
# Manages People                                                 9.024552
# Household Description                                          0.000000
# Tenure in Current Job                                          0.000000
# Metro/Regional                                                 0.000000
# Time Remote Last Year                                          0.000000
# ...

# %%
null_columns=['Org Encouraged Remote Last Year','Collaboration When Remote Last Year',"Easy to Get Permission to Remote Last Year" ,'Org Prepared for Remote Last Year','Recommend Remote Last Year','Common for Org to Remote Last Year']

# %%
data[null_columns]=data[null_columns].fillna(' No Response')

# %%
((data.isnull().sum()/len(data))*100)
# Out:
# Response ID                                                   0.000000
# Birth Year                                                    0.000000
# Gender                                                        0.000000
# Industry                                                      0.000000
# Industry (Detailed)                                           0.000000
# Occupation                                                    0.000000
# Occupation (Detailed)                                         0.000000
# Employment Size                                               0.000000
# Manages People                                                9.024552
# Household Description                                         0.000000
# Tenure in Current Job                                         0.000000
# Metro/Regional                                                0.000000
# Time Remote Last Year                                         0.000000
# ...

# %%
columns_to_replace=['Time Remote Last 3 Months'  ,                                   
'Org Encouraged Remote Last 3 Months' ,                        
'Org Prepared for Remote Last 3 Months',                       
'Common for Org to Remote Last 3 Months',                       
'Easy to Get Permission to Remote Last 3 Months',               
'Collaboration When Remote Last 3 Months'  ,                   
'Recommend Remote Last 3 Months']

# %%
modes=data[columns_to_replace].mode().iloc[0]

# %%
data[columns_to_replace] = data[columns_to_replace].fillna(modes)

# %%
data['Preferred Remote Post-COVID'].value_counts()
# Out:
# Preferred Remote Post-COVID
# 50% - About half of my time             304
# 100% - All of my time                   166
# 20%                                     128
# 80%                                     124
# 60%                                     105
# 40%                                     105
# 30%                                      90
# I would prefer not to work remotely      89
# 70%                                      80
# 90%                                      69
# Less than 10% of my time                 58
# 10%                                      53
# Name: count, dtype: int64

# %%
nulls_columns=['Preferred Remote Post-COVID','Manages People']
data[nulls_columns]=data[nulls_columns].fillna(' No Response')

# %%
data['Manages People'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Response ID                                                   0
# Birth Year                                                    0
# Gender                                                        0
# Industry                                                      0
# Industry (Detailed)                                           0
# Occupation                                                    0
# Occupation (Detailed)                                         0
# Employment Size                                               0
# Manages People                                                0
# Household Description                                         0
# Tenure in Current Job                                         0
# Metro/Regional                                                0
# Time Remote Last Year                                         0
# Org Encouraged Remote Last Year                               0
# Org Prepared for Remote Last Year                             0
# ...

# %%
data.to_csv('dataset_2020.csv', index=False)

# %%
data.head()
# Out:
#    Response ID  Birth Year  Gender  \
# 0            1        1972  Female
# 1            2        1972    Male
# 2            3        1982    Male
# 3            4        1987  Female
# 4            5        1991    Male
#
#                                           Industry  \
# 0                                    Manufacturing
# 1                                  Wholesale Trade
# 2       Electricity, Gas, Water and Waste Services
# 3  Professional, Scientific and Technical Services
# 4                Transport, Postal and Warehousing
#
#                                Industry (Detailed)  \
# 0                       Food Product Manufacturing
# 1                          Other Goods Wholesaling
# 2                                       Gas Supply
# 3  Professional, Scientific and Technical Services
# 4                                  Other Transport
#
#                      Occupation  \
# 0  Clerical and administrative
# 1                      Managers
# ...

# %% [raw]
# df=data.drop(['Response ID'],axis=1)

# %%
for col in df.columns:
    print(f"Column: {col}")
    print(df[col].value_counts())
    print("\n")
# Out:
# Column: Birth Year
# Birth Year
# 1985    52
# 1964    51
# 1990    49
# 1970    48
# 1961    47
# 1960    47
# 1978    46
# 1977    46
# 1980    44
# 1971    42
# 1989    41
# 1987    41
# 1966    40
# 1965    40
# 1962    39
# 1969    39
# 1973    38
# 1988    38
# 1963    38
# 1957    37
# 1986    37
# 1972    37
# 1975    37
# 1959    37
# 1984    36
# 1968    35
# 1976    34
# 1981    33
# 1967    33
# 1983    31
# 1974    30
# 1956    29
# 1958    29
# 1982    29
# 1979    29
# 1991    25
# 1995    23
# 1992    20
# 1994    16
# 1993    13
# 1996    12
# 1955     9
# 2000     9
# 1998     7
# 1997     7
# 1900     2
# 2001     2
# 1999     1
# 1937     1
# 1945     1
# Name: count, dtype: int64
#
#
# Column: Gender
# Gender
# Male              847
# Female            658
# Rather not say      2
# Name: count, dtype: int64
#
#
# Column: Industry
# Industry
# Professional, Scientific and Technical Services    259
# Financial and Insurance Services                   173
# ...
