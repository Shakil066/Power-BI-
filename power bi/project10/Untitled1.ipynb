# %%
# basic python

# %%
a=10
b=11
a==b
# Out:
# False

# %%
if (a==b):
    a= a+10
else:
    b=b-12

# %%
a
# Out:
# 10

# %%
b
# Out:
# -13

# %%
# 1.3.1 Methods of String

# finding the length of a string
print(len(string))

# finding the index of an item/letter
print(string[6])

# multiple strings
s = [ "Our first class", "thursday", "sakib", "internt",'python', 'sakib', 'tasmia', 'hasan', 'imtiaz', 'tayem' ]
print(s)

print(len(s))

# Slicing: separating into 2 parts
print(s[2:])  # specific position to last value
print(s[:8])  # starting to specific value
print(s[:])  # all values

# from backword
print(s[-1])  # only last value
print(s[ :-1])  # all except last value

# interval/frequency
print(s[ : : 2])

# reverse
print(s[ : : -1])

# slicing from both sides
print(s[1:7])

#%%
# concatanate
con = "hello world"
n = " to all of us"
con = con + n # con+n
print(con).upper()/ lower()
#con

# capitalize all the letters
print(con.upper())

m2 = "NEW SENTENCE"
print(m2.lower())

# Skip split and separate
print(con.split("o"))

# count the letter
print(con.count("o"))

print(con.isalnum())

print(con.isdigit())

# finding an item/index
print(con.find("r"))

#%%
# Part 2
# 1.4 List

my_list = [1, 2, 3, 4, 5, "Jehan", "al-amin", "mustakim", "nafi"]
print(my_list)

print(len(my_list))

# indexing and slicing
print(my_list[3])

print(my_list[2:])

# add items manually
my_list += ["class","monday"]
print(my_list)

# append
my_list.append("add me")
print(my_list)

#%%
# new data
l = [ 43, 28, 72, 39, 'sifat', 'yousuf', 'nizam', 'noshin'  ]
print( len(l))

# looks sequence of numbers and string
num = l[ : 4 ]

# adding two values manually
num = num + [ 10, 20 ]
print(num) 

cat = l [ 4:  ]
cat = cat + ['sudarshan']
print(cat)
#%%
# new list
list1 = [ 54, 72, 30, 49, 71, 83, 67, 48, 56]

# adding a new list
num2 = [ 101,102,103 ]
list2 = list1 + num2
print(list2)

# alternate way, using "extend"
list1.extend(num2)
print(list1)

# adding a new value using append 
list2.append( 100)
print(list2)

# adding a new list within a list
list2.append( [50, 51, 52])
print(list2)

# inserting a new value in a specific position
list2.insert(2, 10)
print(list2)

# delete from specific index value
list2.pop(2)
print(list2)

# remove a specific value
list2.remove(103)
print(list2)

list2.pop()
print(list2)

# ascending order
list2.sort()
print(list2)

# reverse/descending
list2.reverse()
print(list2)

# max and min value
print(max(list2))
print(min(list2))

#%%
# creating a matrix
# list wihtin a list

l1 = [1,2,3]
l2 = [4,5,6]
l3 = [7,8,9]

matrix = [l1, l2, l3]

print(matrix)

# finding a column value
print(matrix[1][2])

#%%
# 1.5 Dictionaries (keys: values)
# example 01

my_dict = {"key1": "value1", "key2":"value2"}
print(my_dict)

my_dict = {"k1": 150, "k2": 14.45, "k3": "aziz", "k4":[3,7,3,8,7,3]}
print(my_dict["k2"])

# find specific value
print(my_dict["k4"][4])

# upper
print(my_dict["k3"].upper())

# addition
my_dict["k1"] = my_dict["k1"] + 7
print(my_dict["k1"])

# substraction
print(my_dict["k1"] - 23)

# copy
b = my_dict.copy()
print(b)

# getting a specific value
print(my_dict.get("k1"))

# keys and values
print(my_dict.keys())
print(my_dict.values())

print(my_dict["k4"])

#%%
# nested dictionary
d = { "k1" : { "nest_key" : { "subnest_key": 10 } } }
print(d['k1']['nest_key']['subnest_key'])

nest = { 'one': {'two' : {'three' : [1,2,3] }}}
d3 = nest['one']
print(d3)
d4 = nest['one']['two']
print(d4)
d5 = nest['one']['two']['three']
print(d5)

city1 = { "city": [ {"dhaka":["uttara", "mirpur", "banani"]} , "ctg", "syl", "raj"]}
print(city1["city"][0]["dhaka"][1])

#%%
# Part 3
# 2.1 If-Else Statement

# using string

s_var = "today is our second class"

if "his" in s_var:
    print("yes, its there")
else:
    print("its not there")
    
#%%
# using list with strings

v = [ "ruhit", "sakib", "muhit"  ]

if "muhit" in v:
    print( "yes, its there")
else:
    print("no, its NOT there ")

#%%
# using list with numbers

list3 = [ 54, 76, 31, 49, 71, 85, 67, 48, 56]

if 100 in list3:
    print("okay!")
else:
    print("NOT!")    

#%%
# using "el-if"

num = 0

if num > 0:
    print("positive")
elif num < 0:
    print("negative")
else:
    print("NULL")
    
#%%
# we can input values

m = int(input("input no.: "))
print("your given number is: ", m)

if m > 0:
    print("positive")
elif m < 0:
    print("negative")
else:
    print("neutral")

#%%
# checking el-if conditions with "and" logical operator

m = float(input("input your cgpa: "))

if m > 3.5:
    print("A+")
elif m < 3.5 and m> 3.0:
    print("A")
elif m < 3.0 and m> 2.5:
    print("B")
elif m < 2.5 and m> 2.0:
    print("C")
else:
    print("Fail")
    
#%%    
# checking el-if conditions with range function

cgpa = int(input("Please input number out of 100: "))

if cgpa >= 80:
    print("Grade is : A+")
elif cgpa in range(70,80):
    print("Grade is : A")
elif cgpa in range(60,70):
    print("Grade is : A-")
elif cgpa in range(50,60):
    print("Grade is : B")
elif cgpa in range(40,50):
    print("Grade is : B-") 
elif cgpa in range(30,40):
    print("Grade is : B-") 
else:
    print("Sorry..! Your Grade is Under Fail mark.")
    
#%%
# 2.2 For Loop
# print in a for loop

str2 = "this is our third class"

for c in str2:
    print(c)
    
#%%
# finding sum from a list
sum1 = 0
list3 = [ 54, 76, 31, 49, 71, 85, 67, 48, 56]

for a in list3:
    sum1 += a 

print(sum1)

sum1=0
for i in list3[ :2]:
    sum1 += i
    
print(sum1)

#%%
# finding odd and even numbers
list3 = [ 54, 76, 31, 49, 71, 85, 67, 48, 56]

for num in list3:
    if num%2==0:
        print("even")
    else:
        print("odd")
         
#%%
# separate string and numbers
t1 = [ 18,15,"sakib", 24,"mash",33,28,30,25,"mushi","colince",61,43,26,"tamim"
      ,77,"riyad",41,38,59,"fizz",'sifat',43, 28, 'nizam',72, 'noshin', 39,  'yousuf' ]
st = []
o = []
e = []
for i in t1:
    if isinstance( i, str):
        st.append(i)
    elif i % 2 == 0:
        e.append(i)
    else:
        o.append(i)
        
        
print("only odd numbers: ", o)
print("only strings: ", st)
print("only even numbers: ", e)

#%%
l = [ 45, 72, 34, 12, 49 ]

for i in l:
    if i%2 == 0:
        for j in l:
            j = i + 5
        print("adding 5 with even: ", j)
    else:
        print("odd number", i)
        
#%%
v = [ 18,15,24,33,28,30,35,61,43, 51,46,72,39,17 ]
m = []
n = []
for l in v: 
    if l % 2 == 0:
        l = l + 100
        m.append(l)
    else:
        l = l - 100
        n.append(l)

print("the list of new even numbers are: ", m)
print("the list of new odd numbers are: ", n) 
#%%
##############################################################
# 2.3 Loop Control statement
# 2.3.1 break

# exmaple 01: using string
for v in "Sakib":
    if v == "i":
        break
        print(v)
    else:
        print(v)
        
print("its done")

#%%
# exmaple 02: using numbers
l = [ 21,34,16,19,100, 26,29,41,38,59]

for i in l:
    if i > 50:
        break
        #print(i)
        
    else:
        print(i)
        
print("its done")

#%%
# 2.3.2 continue
# exmaple 03: using string
for v in "Sakib":
    if v == "i":
        continue
        print(v)
    else:
        print(v)
        
print("its done")  

#%%
# exmaple 04: using numbers
l = [ 21,34,16,19,100, 26,29,41,38,59]

for i in l:
    if i > 50:
        continue
        #print(i)
        
    else:
        print(i)
        
print("its done")
#%%
# example 05: for-if-continue
l = [ 21,34,16,19,100, 26,29,41,38,59]
sum_total = 0

# loop
for i in l:
    if i == 19 or i == 29:
        continue
    #print(i)
    sum_total += i  # increment
    
#print(i)
print(sum_total)  #  final ans

#%%
# example 06: for-if-break
l = [ 21,34,16,19,100, 26,29,41,38,59]
sum_total = 0

# loop
for i in l:
    if i == 19 or i == 29:
        break
    #print(i)
    sum_total += i  # increment
    
#print(i)
print(sum_total)  #  final ans
#%%
####################################################################
#%%
# Combined operation of break and continue
# example 07
for x in range(-10, 30):
    if x == 2:
        continue
    elif x > 8:
        break
    print(x)

#%%
# example 08
v = [ 18,15,24,33,28,30,35,61,43 ]
for x in v:
    if x == 24:
        continue 
    elif x == 35:
        break 
    print(x)
    
#%%
# example 09
a = [ 21,34,16,19,100, 26,29,41,38,59]

# print(sum(a))  # 63
list_sum = 0

for num in a:
    if num == 19:
        continue  
    elif num == 29:
        break 
    else:
        list_sum += num

print(list_sum)

#%%
####################################################################
#%%

# 2.3.3 While Loop

x = 0

while x < 10:
    print(x)
    x = x + 1

#%%
count = 0
while (count < 16):
    print(count)
    count += 1
    
print("all done")

#%%
# practice
# Finding prime number

for num in range (2,20):
    for i in range(2, num):
        if num % i ==0:
            j = num / i
            print("%d equals %d*%d" %(num, i, j))
            break
    
    else:
        print(num, "is a Prime number")
        
# alternate way
print ("prime numbers between are")
for num in range (1,30):
    if num > 1: # All prime number are greater than 1
        for i in range (2, num):
            if (num % i) == 0:
                break
        else:
            print(num)
#%%
####################################################################
#%%
# 3.1 Modulo

l = [1,2,3,4,5,6,7,8]

for num in l:
    if num%2 == 0:
        print(num, " is an even number")

for num in l:
    if num%2 !=0:
        print(num, " is an odd number")

print("done")


#%%
for num in l:
    if num%2 == 0:
        print(num, " is an even number")
    else:
        print(num, " is an odd number")
        
#%%
####################################################################
#%%

# 3.2 List Comprehension

l = []

for letter in "language":
    l.append(letter)

print(l)


l= [ letter for letter in "language"]
print(l)

l2 = [ k for k in "python" ]
print(l2)

print([ n for n in "python" ])

lst = [ x**2  for x in range(2,7)]
print(lst)

lst2 = [num for num in range(10) if num %2 == 0 ]
print(lst2)

#%%
l2 = [ 18,15,"sakib", 24,"mash",33,28,30,25,"mushi","colince",61,43,26,"tamim"
      ,77,"riyad",41,38,59,"fizz",'sifat',43, 28, 'nizam',72, 'noshin', 39,  'yousuf' ]
n = [x for x in l2 if isinstance(x, int)]
s = [x for x in l2 if isinstance(x, str)]

print(s)

lst = [num**3 for num in n if num % 2 == 0 ]
print(lst)

#%%
# nestet list comprehension

mst = [ (2*m) for m in [x**2 for x in n] if m%2==0   ]
print(mst)

mst2 = [ m for m in ((2*x) for x in range(1,11)) if (m>5)   ]
print(mst2)

lst = [ (x+10) for x in [x**2 for x in range (1,10)]]
print(lst)
#%%
# celcius to farenheit

c = [97,98,99,100,101,102]

#print(cel)

far = [(num*(9/5) + 32) for num in c]
print(far)

#%%
####################################################################
#%%
# 4.1 Tuple

t = (1,2,3,4,5)
print(len(t))

print(t[3])

# list of tuples
s = (11,12,13,14,15)

list_of_tuple = [s,t]
print(list_of_tuple)

print(list_of_tuple[0][::-1])


(age, income) = "40, 200000".split(",")
print(age)
print(income)

#%%
# unpacking tuple

m = [ (1,2), (3,4), (5,6)]

print(m[0][1])

# using loop
for t in m:
    print(t[0])

#%%
# for loop in tuple
d = [ (23,62), (54,70) ,(14,20), (41,38) ]

for (i,j) in d:
    i += 100
    j -= 50
    print(i)
    print(j)
    print("=====")
#%%
# for loop in the dictionary
d = { 'k1':1,  'k2': 2, 'k3': 3  }

print(d)

for num in d:
    print(num)
    
for (k,v) in d.items():
    print((k,v))
#%%
####################################################################
#%%

# 5.1 function

def number(x):    # name(arguement)
    return x**2

print(number(8))

def square(f, x):
    return f(x)

print(square(number, 6))

#  lambda function
print(square(lambda x: x*x, 3))

#%%
# example 02
def wednesday(x, y):
    x = (x**2) + (4*x) -3
    y = (y**3) + (4*y) + 6
    z = x + y
    print(z)
    return

wednesday(3, 2)

#%%
def python(x):
    print("this is our third class")
    return

python(1)

#%%
# keyword arguement

def python(x):
    print("fourth class")
    return

#x = 1
print(python(0))

#%%
# default argument

def laptop (x, y=50):
    print(x,y)
    return

laptop(8)

#%%
# default argument
def wednesday(x, y):  # case 1
    y =10  # case 2: pass by value argument
    x = (x**2) + (4*x) -3
    y = (y**3) + (4*y) + 6
    z = x + y
    print(z)
    return

wednesday(3,2)

#%%
# valriable langth argument

def mouse(m, *l):
    print(m)
    for b in l:
        print(b)
    return

mouse(1000, 12, 14, 15,17, 20)

#%%
# pass by value argument

def pen(x):
    x= 60
    print(x)
    return

x = 1000
pen(10)

print(x)

#%%
# Pass by reference
a = [100, 120, 124, 131, 150]
def phone(x):
    x[0] = 500
    print(x)
    return

phone(a)

print(a)

#%%
####################################################################
#%%
# sample program for making  a list of numbers and sum of 
# inputted number from the list:

Total = int(input("How Many Number You want to Sum : "))
numberlist= []
numbersum = 0

for i in range(Total):
    inputnumber = int(input("Input:"))
    numberlist.append(inputnumber)
    
    
print("list is: ", numberlist)
print("Sum: ", sum(numberlist))

#%%
# module ends here

# %%
s = [ "Our first class", "thursday", "sakib", "internt",'python', 'sakib', 'tasmia', 'hasan', 'imtiaz', 'tayem' ]
print(s)

print(len(s))
# Out:
# ['Our first class', 'thursday', 'sakib', 'internt', 'python', 'sakib', 'tasmia', 'hasan', 'imtiaz', 'tayem']
# 10

# %%
print(s[3:])
# Out:
# ['internt', 'python', 'sakib', 'tasmia', 'hasan', 'imtiaz', 'tayem']

# %%
print(s[-1])  # only last value
print(s[ :-1])  # all except last value

# %%
print(s[-1])
# Out:
# tayem

# %%
print(s[ :-1])
# Out:
# ['Our first class', 'thursday', 'sakib', 'internt', 'python', 'sakib', 'tasmia', 'hasan', 'imtiaz']

# %%
print(s[: :4])
# Out:
# ['Our first class', 'python', 'imtiaz']

# %%
print(s[ : : -1])
# Out:
# ['tayem', 'imtiaz', 'hasan', 'tasmia', 'sakib', 'python', 'internt', 'sakib', 'thursday', 'Our first class']

# %%
# concatanate
con = "hello world"
n = " to all of us"
con = con + n # con+n
print((con).upper())
#con

# capitalize all the letters
print(con.upper())

m2 = "NEW SENTENCE"
print(m2.lower())

# Skip split and separate
print(con.split("o"))

# count the letter
print(con.count("o"))

print(con.isalnum())

print(con.isdigit())

# finding an item/index
print(con.find("r"))
# Out:
# HELLO WORLD TO ALL OF US
# HELLO WORLD TO ALL OF US
# new sentence
# ['hell', ' w', 'rld t', ' all ', 'f us']
# 4
# False
# False
# 8

# %%
con.split("a")
# Out:
# ['hello world to ', 'll of us']

# %%
ist1 = [ 54, 72, 30, 49, 71, 83, 67, 48, 56]
ist

# %%
# 1.5 Dictionaries (keys: values)
# example 01

my_dict = {"key1": "value1", "key2":"value2"}
print(my_dict)

my_dict = {"k1": 150, "k2": 14.45, "k3": "aziz", "k4":[3,7,3,8,7,3]}
print(my_dict["k2"])

# find specific value
print(my_dict["k4"][4])

# upper
print(my_dict["k3"].upper())

# addition
my_dict["k1"] = my_dict["k1"] + 7
print(my_dict["k1"])

# substraction
print(my_dict["k1"] - 23)

# copy
b = my_dict.copy()
print(b)

# getting a specific value
print(my_dict.get("k1"))

# keys and values
print(my_dict.keys())
print(my_dict.values())

print(my_dict["k4"])

# nested dictionary
d = { "k1" : { "nest_key" : { "subnest_key": 10 } } }
print(d['k1']['nest_key']['subnest_key'])

nest = { 'one': {'two' : {'three' : [1,2,3] }}}
d3 = nest['one']
print(d3)
d4 = nest['one']['two']
print(d4)
d5 = nest['one']['two']['three']
print(d5)

city1 = { "city": [ {"dhaka":["uttara", "mirpur", "banani"]} , "ctg", "syl", "raj"]}
print(city1["city"][0]["dhaka"][1])
# Out:
# {'key1': 'value1', 'key2': 'value2'}
# 14.45
# 7
# AZIZ
# 157
# 134
# {'k1': 157, 'k2': 14.45, 'k3': 'aziz', 'k4': [3, 7, 3, 8, 7, 3]}
# 157
# dict_keys(['k1', 'k2', 'k3', 'k4'])
# dict_values([157, 14.45, 'aziz', [3, 7, 3, 8, 7, 3]])
# [3, 7, 3, 8, 7, 3]
# 10
# {'two': {'three': [1, 2, 3]}}
# {'three': [1, 2, 3]}
# [1, 2, 3]
# mirpur

# %%
for v in "Sakib":
    if v == "i":
        break
        print(v)
    else:
        print(v)
        
print("its done")
# Out:
# S
# a
# k
# its done

# %%
Total = int(input("How Many Number You want to Sum : "))
numberlist= []
numbersum = 0

for i in range(Total):
    inputnumber = int(input("Input:"))
    numberlist.append(inputnumber)
    
    
print("list is: ", numberlist)
print("Sum: ", sum(numberlist))
# Out:
# How Many Number You want to Sum :  6
# Input: 34
# Input: 45
# Input: 67
# Input: 67
# Input: 65
# Input: 43
# list is:  [34, 45, 67, 67, 65, 43]
# Sum:  321

# %%
# Pass by reference
a = [100, 120, 124, 131, 150]
def phone(x):
    x[0] = 500
    print(x)
    return

phone(a)
# Out:
# [500, 120, 124, 131, 150]

# %%
# example 05: for-if-continue
l = [ 21,34,16,19,100, 26,29,41,38,59]
sum_total = 0

# loop
for i in l:
    if i == 19 or i == 29:
        break
    print(i)
    sum_total += i  # increment
    
#print(i)
print(sum_total)
# Out:
# 21
# 34
# 16
# 71
